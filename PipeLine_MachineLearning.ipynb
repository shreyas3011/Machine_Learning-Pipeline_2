# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyas3011/Machine_Learning-Pipeline_2/blob/main/PipeLine_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.pipeline import Pipeline

# %%
#numerical preprocesssing pipeline
numerical_processer=Pipeline(steps=[
    ('imputer',SimpleImputer(missing_values=np.nan,strategy='mean')),
    ('scaler',StandardScaler())
])

# %%
numerical_processer
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())])

# %%
#catogiriacl preprocesinh pipeline
catogerical_preprocesser=Pipeline(steps=[
    ('imputation_constant',SimpleImputer(fill_value='missing',strategy='constant')),
    ('encoder',OneHotEncoder(handle_unknown='ignore'))
])

# %%
catogerical_preprocesser
# Out:
# Pipeline(steps=[('imputation_constant',
#                  SimpleImputer(fill_value='missing', strategy='constant')),
#                 ('encoder', OneHotEncoder(handle_unknown='ignore'))])

# %%
#combininng preprocesser techinques
from sklearn.compose import ColumnTransformer
preprocesser=ColumnTransformer(
    [('numerical',numerical_processer,['age','height']),
    ('catogerical',catogerical_preprocesser,['gender','city'])]
)

# %%
preprocesser
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age', 'height']),
#                                 ('catogerical',
#                                  Pipeline(steps=[('imputation_constant',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['gender', 'city'])])

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# %%
pipe=make_pipeline(preprocesser,LogisticRegression())

# %%
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'height']),
#                                                  ('catogerical',
#                                                   Pipeline(steps=[('imputation_constant',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('encoder',
# ...
